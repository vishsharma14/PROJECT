# %% [markdown]
# <a href="https://colab.research.google.com/github/vishsharma14/PROJECT/blob/main/KerasFunctionalModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#non Linear Model

# %%
from keras.models import Model

# %%
model = Model(inputs= x,outputs=[output1,output2])

# %%
from keras.layers import *

# %%
x = Input(shape=(3,))

# %%
hidden1 = Dense(128,activation ='relu')(x)
hidden2 = Dense(64,activation='relu')(hidden1)

output1 = Dense(1,activation='linear')(hidden2)
output2 = Dense(1,activation='sigmoid')(hidden2)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 3)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 128)       │        512 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │      8,256 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1)         │         65 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
#Functional API Multiple Input

# %%
from keras.layers import *
from keras.models import Model

# %%
inputA = Input(shape=(32,))
inputB = Input(shape=(128,))

# %%
x = Dense(8,activation='relu')(inputA)
x1 = Dense(4,activation='relu')(x)

# %%
y = Dense(64,activation ="relu")(inputB)
y1 = Dense(32,activation = 'relu')(y)
y2 = Dense(4,activation='relu')(y1)

# %%
combined = concatenate([x1,y2])

# %%
z = Dense(2,activation='relu')(combined)
z1 = Dense(1,activation='linear')(z)

# %%
model = Model(inputs=[inputA,inputB],outputs=z1)

# %% [markdown]
# It seems like there's an issue with the Graphviz installation, which `plot_model` relies on. Let's try installing/updating it.

# %%
# Install Graphviz system-level packages
# !apt-get install -y graphviz

# Install/upgrade the Python graphviz library
# !pip install graphviz

print("Graphviz installation/upgrade complete. Please try running the plot_model cell again.")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# ...
# Graphviz installation/upgrade complete. Please try running the plot_model cell again.

# %%
from keras.utils import plot_model
plot_model(model)
